# %%
import pandas as pd

# %%
# Series
series1 = pd.Series([1,2,3,4,5], index = [0,1,2,3,4]) 
print(series1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# DataFrame
# Create data frame from lists
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data, columns = ['Name','Age'])
print(df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
# Show current working directory - the directory where all your files are saved by default
import os
os.getcwd()
# Out:
# 'C:\\Users\\Sarah\\Faris Stuff\\USM Data Science Masters Files\\Jupyter Labs'

# %%
# Set path for new working directory
path = "C:/Users/Sarah/Faris Stuff/USM Data Science Masters Files/CDS503/Week 3 - 02 Mar/Data"
os.chdir(path) 
# Check to see if current directory has changed
os.getcwd()
# Out:
# 'C:\\Users\\Sarah\\Faris Stuff\\USM Data Science Masters Files\\CDS503\\Week 3 - 02 Mar\\Data'

# %%
# Read data from CSV to a data frame named df
df = pd.read_csv('titanic.csv') 
# Display the data
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250

# %%
df.tail(3)
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1       1            Mr. Karl Howell Behr    male  26.0
# 886         0       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 884                        1                        2  23.45
# 885                        0                        0  30.00
# 886                        0                        0   7.75

# %%
# Display the metadata or summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
# Display the rows and columns
df.shape
# Out:
# (887, 8)

# %%
# Display column names
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
 # Rename 2 columns: Siblings/Spouses Aboard and Parents/Children Aboard
df.rename(columns = {'Siblings/Spouses Aboard':'Siblings_Spouses', 'Parents/Children Aboard':'Parents_Children'}, inplace=True) 
# Display column names
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings_Spouses',
#        'Parents_Children', 'Fare'],
#       dtype='object')

# %%
# Option 1: Set the names to each column in a list - change the column names to lowercase
# df.columns = ['survived', 'pclass', 'name', 'sex', 'age', 'siblings_spouses', 'parents_children', 'fare']
# df.columns 

# Option 2: Can also use a for loop to access each element in the column name list
df.columns = [col.lower() for col in df]
df.columns
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'siblings_spouses',
#        'parents_children', 'fare'],
#       dtype='object')

# %%
# Specify the desired columns in a new selected_col list
selected_col = ['survived', 'pclass', 'sex', 'age', 'fare'] 
# Create a new data frame to store data from selected columns
df_new = df[selected_col] 
# Display the first 5 rows in df_new
df_new.head()
# Out:
#    survived  pclass     sex   age     fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
# Display the data types of each column
df_new.dtypes
# Out:
# survived      int64
# pclass        int64
# sex          object
# age         float64
# fare        float64
# dtype: object

# %%
# Show basic statistics for numeric variables
df.describe()
# Out:
#          survived      pclass         age  siblings_spouses  parents_children  \
# count  887.000000  887.000000  887.000000        887.000000        887.000000
# mean     0.385569    2.305524   29.471443          0.525366          0.383315
# std      0.487004    0.836662   14.121908          1.104669          0.807466
# min      0.000000    1.000000    0.420000          0.000000          0.000000
# 25%      0.000000    2.000000   20.250000          0.000000          0.000000
# 50%      0.000000    3.000000   28.000000          0.000000          0.000000
# 75%      1.000000    3.000000   38.000000          1.000000          0.000000
# max      1.000000    3.000000   80.000000          8.000000          6.000000
#
#             fare
# count  887.00000
# mean    32.30542
# std     49.78204
# min      0.00000
# 25%      7.92500
# 50%     14.45420
# 75%     31.13750
# max    512.32920

# %%
# View the mean age, mean siblings_spouses, mean parents_children and mean fare based on each unique value of pclass
# Specify the desired columns in a new selected_col list
selected_col = ['pclass', 'age', 'siblings_spouses', 'parents_children', 'fare'] 
# Create a new data frame to store data from selected columns
df_temp = df[selected_col] 
# Display the first 5 rows in df_new
df_temp.groupby('pclass').mean()
# Out:
#               age  siblings_spouses  parents_children       fare
# pclass
# 1       38.788981          0.416667          0.356481  84.154687
# 2       29.868641          0.402174          0.380435  20.662183
# 3       25.188747          0.620123          0.396304  13.707707

# %%
# Show basic statistics for categorical variables
df['sex'].describe()
# Out:
# count      887
# unique       2
# top       male
# freq       573
# Name: sex, dtype: object

# %%
# Count the occurrences of each class
df['sex'].value_counts()
# Out:
# sex
# male      573
# female    314
# Name: count, dtype: int64

# %%
# Calculate the least occurring value in a categorical column
df['sex'].min()
# Out:
# 'female'

# %%
# Calculate the most occurring value in a categorical column
df['sex'].max()
# Out:
# 'male'

# %%
df.dtypes
# Out:
# survived              int64
# pclass                int64
# name                 object
# sex                  object
# age                 float64
# siblings_spouses      int64
# parents_children      int64
# fare                float64
# dtype: object

# %%
## Convert 'survived' and 'pclass' to string - why? 
# df[['survived', 'pclass']] = df[['survived', 'pclass']].astype(str)

# %%
# Import matplotlib library
import matplotlib.pyplot as plt 

# Set font and plot size
plt.rcParams.update({'font.size': 10, 'figure.figsize': (5, 4)})
# Plot a histogram to study the distribution of age
df['age'].plot(kind='hist', title='Age')
# Out:
# <Axes: title={'center': 'Age'}, ylabel='Frequency'>

# %%
df['age'].plot(kind='box', title='Age')
# Out:
# <Axes: title={'center': 'Age'}>

# %%
plt.rcParams.update({'font.size': 8, 'figure.figsize': (5, 4)})
df.boxplot(column='age', by='survived')
# Out:
# <Axes: title={'center': 'age'}, xlabel='survived'>

# %%
# Plot a bar chart based on count of each label 
df['survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
df_temp.corr()
# Out:
#                     pclass       age  siblings_spouses  parents_children  \
# pclass            1.000000 -0.391492          0.085026          0.020252
# age              -0.391492  1.000000         -0.297669         -0.193741
# siblings_spouses  0.085026 -0.297669          1.000000          0.414244
# parents_children  0.020252 -0.193741          0.414244          1.000000
# fare             -0.548919  0.112329          0.158839          0.215470
#
#                       fare
# pclass           -0.548919
# age               0.112329
# siblings_spouses  0.158839
# parents_children  0.215470
# fare              1.000000

# %%
# Plot a scatterplot based on two variables: age and fare
df.plot(kind='scatter', x='age', y='fare', title='Age vs Fare')
# Out:
# <Axes: title={'center': 'Age vs Fare'}, xlabel='age', ylabel='fare'>
